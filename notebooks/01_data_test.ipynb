# %%
import pybaseball as pb
import pandas as pd

pb.cache.enable()

# %%
batting = pb.batting_stats_bref(2025)
print(batting.shape)
batting.head()
# Out:
# (675, 28)
#                       Name  Age  #days     Lev          Tm    G   PA   AB   R  \
# 1                CJ Abrams   24    214  Maj-NL  Washington  144  635  580  92
# 2             Wilyer Abreu   26    210  Maj-AL      Boston  116  422  378  53
# 3            Maximo Acosta   22    228  Maj-NL       Miami   19   61   54   7
# 4   Luisangel Acu\xc3\xb1a   23    215  Maj-NL    New York   95  193  175  30
# 5  Ronald Acu\xc3\xb1a Jr.   27    214  Maj-NL     Atlanta   95  412  338  74
#
#      H  ...  SH  SF  GDP  SB  CS     BA    OBP    SLG    OPS   mlbID
# 1  149  ...   1   3    5  31   3  0.257  0.315  0.433  0.748  682928
# 2   92  ...   1   3    8   6   3  0.243  0.314  0.463  0.777  677800
# 3   11  ...   0   0    0   1   2  0.204  0.295  0.389  0.684  691185
# 4   41  ...   2   1    6  16   1  0.234  0.293  0.274  0.567  682668
# 5   98  ...   0   0    5   9   1  0.290  0.417  0.518  0.935  660670
#
# [5 rows x 28 columns]

# %%
print(f"Total players: {batting.shape[0]}")
print(f"Total columns: {batting.shape[1]}")
# Out:
# Total players: 654
# Total columns: 28

# %%
print(batting.columns.tolist())
# Out:
# ['Name', 'Age', '#days', 'Lev', 'Tm', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'IBB', 'SO', 'HBP', 'SH', 'SF', 'GDP', 'SB', 'CS', 'BA', 'OBP', 'SLG', 'OPS', 'mlbID']

# %%
batting.isnull().sum()
# Out:
# Name     0
# Age      0
# #days    0
# Lev      0
# Tm       0
# G        0
# PA       0
# AB       0
# R        0
# H        0
# 2B       0
# 3B       0
# HR       0
# RBI      0
# BB       0
# IBB      0
# SO       0
# HBP      0
# SH       0
# SF       0
# GDP      0
# SB       0
# CS       0
# BA       3
# OBP      3
# SLG      3
# OPS      3
# mlbID    0
# dtype: int64

# %%
batting.to_csv('../data/raw/batting_2024.csv', index=False)
print("Saved")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 batting.to_csv('../data/raw/batting_2024.csv', index=False)
#       2 print("Saved")
#
# File ~\Projects\baseball-fantasy-projections\venv\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3984             float_format=float_format,
#    3985             decimal=decimal,
#    3986         )
#    3987
# -> 3988         return DataFrameRenderer(formatter).to_csv(
#    3989             path_or_buf,
#    3990             lineterminator=lineterminator,
#    3991             sep=sep,
#
# File ~\Projects\baseball-fantasy-projections\venv\Lib\site-packages\pandas\io\formats\format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File ~\Projects\baseball-fantasy-projections\venv\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
#     272     self._save()
#
# File ~\Projects\baseball-fantasy-projections\venv\Lib\site-packages\pandas\io\common.py:793, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     791 # Only for write methods
#     792 if "r" not in mode and is_path:
# --> 793     check_parent_directory(str(handle))
#     795 if compression:
#     796     if compression != "zstd":
#     797         # compression libraries do not like an explicit text-mode
#
# File ~\Projects\baseball-fantasy-projections\venv\Lib\site-packages\pandas\io\common.py:652, in check_parent_directory(path)
#     650 parent = Path(path).parent
#     651 if not parent.is_dir():
# --> 652     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '..\data\raw'

# %%
import os

os.makedirs('../data/raw', exist_ok=True)
os.makedirs('../data/processed', exist_ok=True)
print("Folders created")
# Out:
# Folders created

# %%
batting.to_csv('../data/raw/batting_2024.csv', index=False)
print("Saved")
# Out:
# Saved

# %%
batting_2023 = pb.batting_stats_bref(2023)
batting_2023.to_csv('../data/raw/batting_2023.csv', index=False)
print(f"2023 players: {batting_2023.shape[0]}")
# Out:
# 2023 players: 660

# %%
from src.configuration import SCORING
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from src.configuration import SCORING
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys
sys.path.append('..')

# %%
from src.configuration import SCORING

# %%
batting["1B"] = batting["H"] - batting["2B"] - batting["3B"] - batting["HR"] #singles not recorded
batting["fantasy_points"] = (
    batting["1B"] * SCORING["single"] +
    batting["2B"] * SCORING["double"] +
    batting["3B"] * SCORING["triple"]+
    batting["HR"] * SCORING["home_run"]+
    batting["BB"] * SCORING["walk"] +
    batting["R"] * SCORING["run"] +
    batting["RBI"] * SCORING["rbi"] +
    batting["SB"] * SCORING["stolen_base"]+
    batting["SO"] * SCORING["strikeout"]
    )

# %%
# 93                 Byron Buxton   66  21   7  35   41   97   83  24  148
# 261            Gunnar Henderson  102  34   5  17   62   85   68  30  137
# 249                Bryce Harper   74  33   0  27   73   73   75  12  124
# 175                Jarren Duran   90  41  13  16   60   87   84  24  173
# 326              Alejandro Kirk  105  20   0  20   57   56   89   1   72
# 629              Gleyber Torres  103  24   0  17   88   81   75   4  111
# 576            Tyler Soderstrom   95  34   1  25   55   75   93   8  141
# 248                    Ian Happ   83  33   0  25   89   90   83   6  164
# 36              Randy Arozarena   93  33   1  28   68  105   78  36  210
# 443               Brandon Nimmo  102  27   0  25   50   81   92  13  141
# 593                Trevor Story  111  29   0  26   33   93   99  32  180
# 331                  Nick Kurtz   58  26   2  36   63   90   86   2  151
# 233                Riley Greene   91  33   1  37   48   88  113   2  210
#
#      fantasy_points
# 455             638
# 303             628
# 583             556
# 492             547
# 237             546
# 496             528
# 554             513
# 476             512
# 584             494
# 347             468
# 64              465
# 690             461
# 523             459
# 437             458
# 70              452
# 101             448
# 114             442
# 20              440
# 606             440
# 637             436
# 276             427
# 71              425
# 470             423
# 219             422
# 162             420
# 209             419
# 361             413
# 640             411
# 166             411
# 456             411
# 530             397
# 37              396
# 332             393
# 374             392
# 600             390
# 91              390
# 154             389
# 603             382
# 128             382
# 134             380
# 146             377
# 638             373
# 21              373
# 123             372
# 696             370
# 485             368
# 672             368
# 93              366
# 261             361
# 249             357
# 175             357
# 326             356
# 629             356
# 576             356
# 248             353
# 36              351
# 443             351
# 593             350
# 331             350
# 233             349

# %%
from pybaseball import statcast
from pybaseball import statcast_batter_expected_stats
savant_batting = statcast_batter_expected_stats(2025)
print(savant_batting.columns.tolist())
savant_batting.head()
# Out:
# ['last_name, first_name', 'player_id', 'year', 'pa', 'bip', 'ba', 'est_ba', 'est_ba_minus_ba_diff', 'slg', 'est_slg', 'est_slg_minus_slg_diff', 'woba', 'est_woba', 'est_woba_minus_woba_diff']
#   last_name, first_name  player_id  year   pa  bip     ba  est_ba  \
# 0     Lindor, Francisco     596019  2025  732  520  0.267   0.260
# 1        Devers, Rafael     646240  2025  729  419  0.252   0.244
# 2        Ohtani, Shohei     660271  2025  727  426  0.282   0.274
# 3       Schwarber, Kyle     656941  2025  724  408  0.240   0.249
# 4           Olson, Matt     621566  2025  724  453  0.272   0.249
#
#    est_ba_minus_ba_diff    slg  est_slg  est_slg_minus_slg_diff   woba  \
# 0                 0.007  0.466    0.454                   0.012  0.350
# 1                 0.008  0.479    0.487                  -0.008  0.365
# 2                 0.008  0.622    0.649                  -0.027  0.418
# 3                -0.009  0.563    0.581                  -0.018  0.391
# 4                 0.023  0.484    0.492                  -0.008  0.366
#
#    est_woba  est_woba_minus_woba_diff
# 0     0.345                     0.005
# 1     0.367                    -0.002
# 2     0.425                    -0.007
# 3     0.401                    -0.010
# 4     0.360                     0.006

# %%
import pybaseball
[x for x in dir(pybaseball) if 'stat' in x.lower()]
# Out:
# ['batting_stats',
#  'batting_stats_bref',
#  'batting_stats_range',
#  'fielding_stats',
#  'league_batting_stats',
#  'league_pitching_stats',
#  'pitching_stats',
#  'pitching_stats_bref',
#  'pitching_stats_range',
#  'split_stats',
#  'statcast',
#  'statcast_batter',
#  'statcast_batter_exitvelo_barrels',
#  'statcast_batter_expected_stats',
#  'statcast_batter_percentile_ranks',
#  'statcast_batter_pitch_arsenal',
#  'statcast_catcher_framing',
#  'statcast_catcher_poptime',
#  'statcast_fielding',
#  'statcast_outfield_catch_prob',
#  'statcast_outfield_directional_oaa',
#  'statcast_outfielder_jump',
#  'statcast_outs_above_average',
#  'statcast_pitcher',
#  'statcast_pitcher_arsenal_stats',
#  'statcast_pitcher_exitvelo_barrels',
#  'statcast_pitcher_expected_stats',
#  'statcast_pitcher_percentile_ranks',
#  'statcast_pitcher_pitch_arsenal',
#  'statcast_pitcher_spin_dir_comp',
#  'statcast_running',
#  'statcast_running_splits',
#  'statcast_single_game',
#  'statcast_sprint_speed']

# %%
savant_batting = pd.read_csv(r"..\data\raw\savant_basic_stats.csv")
print(savant_batting.columns.tolist())
savant_batting.head()
# Out:
# ['last_name, first_name', 'player_id', 'year', 'single', 'double', 'triple', 'home_run', 'strikeout', 'walk', 'b_rbi', 'b_total_bases', 'r_total_stolen_base', 'r_run']
#   last_name, first_name  player_id  year  single  double  triple  home_run  \
# 0        Devers, Rafael     646240  2025      85      33       0        35
# 1        Martin, Austin     668885  2025      34       8       1         1
# 2           Díaz, Elias     553869  2025      36       7       0         9
# 3             Elko, Tim     671284  2025       4       1       0         4
# 4          Paris, Kyren     677347  2025      13       4       1         6
#
#    strikeout  walk  b_rbi  b_total_bases  r_total_stolen_base  r_run
# 0        192   112    109            291                    1     99
# 1         31    22      7             57                   11     22
# 2         74    21     29             86                    0     34
# 3         30     5      8             22                    1      6
# 4         59    10     11             48                    7     20

# %%
savant_batting["fantasy_points"] = (
    savant_batting["single"] * SCORING["single"] +
    savant_batting["double"] * SCORING["double"] +
    savant_batting["triple"] * SCORING["triple"] +
    savant_batting["home_run"] * SCORING["home_run"] +
    savant_batting["walk"] * SCORING["walk"]+
    savant_batting["b_rbi"] * SCORING["rbi"] +
    savant_batting["r_run"] * SCORING["run"]+
    savant_batting["r_total_stolen_base"] * SCORING["stolen_base"] +
    savant_batting["strikeout"] * SCORING["strikeout"]
        )

# %%
savant_batting[["last_name, first_name", "fantasy_points"]
    ].sort_values("fantasy_points", ascending=False).head(30)
# Out:
#       last_name, first_name  fantasy_points
# 205            Judge, Aaron             599
# 151          Ohtani, Shohei             570
# 235              Soto, Juan             556
# 534           Ramírez, José             522
# 54         Perdomo, Geraldo             512
# 336            Raleigh, Cal             509
# 265         Schwarber, Kyle             504
# 392       Lindor, Francisco             468
# 529         Witt Jr., Bobby             461
# 463         Bellinger, Cody             449
# 491        Caminero, Junior             448
# 369  Guerrero Jr., Vladimir             448
# 428        Springer, George             445
# 189         Carroll, Corbin             442
# 257            Alonso, Pete             440
# 116     Tatis Jr., Fernando             439
# 508        Rodríguez, Julio             432
# 185     Pasquantino, Vinnie             423
# 360          Garcia, Maikel             423
# 301            Tucker, Kyle             420
# 0            Devers, Rafael             420
# 272            Naylor, Josh             419
# 39            Betts, Mookie             417
# 494             Díaz, Yandy             411
# 513             Olson, Matt             411
# 496          Machado, Manny             407
# 215            Bichette, Bo             406
# 536           Hoerner, Nico             405
# 16             Turner, Trea             404
# 217           Rooker, Brent             397
